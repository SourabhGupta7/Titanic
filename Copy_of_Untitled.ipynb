# %% [markdown]
# <a href="https://colab.research.google.com/github/SourabhGupta7/Titanic/blob/master/Copy_of_Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import sklearn as sk
import seaborn as sns
df=pd.read_csv("https://raw.githubusercontent.com/SourabhGupta7/Titanic/master/test.csv")
df2=pd.read_csv("https://raw.githubusercontent.com/SourabhGupta7/Titanic/master/gender_submission.csv")
df.head(10)
# Out:
#    PassengerId  Pclass  ... Cabin Embarked
# 0          892       3  ...   NaN        Q
# 1          893       3  ...   NaN        S
# 2          894       2  ...   NaN        Q
# 3          895       3  ...   NaN        S
# 4          896       3  ...   NaN        S
# 5          897       3  ...   NaN        S
# 6          898       3  ...   NaN        Q
# 7          899       2  ...   NaN        S
# 8          900       3  ...   NaN        C
# 9          901       3  ...   NaN        S
#
# [10 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.drop(["Cabin"],axis=1).head()
# Out:
#    PassengerId  Pclass  ...     Fare Embarked
# 0          892       3  ...   7.8292        Q
# 1          893       3  ...   7.0000        S
# 2          894       2  ...   9.6875        Q
# 3          895       3  ...   8.6625        S
# 4          896       3  ...  12.2875        S
#
# [5 rows x 10 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(x="Pclass",y="Age",data=df)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df['Embarked'].value_counts()
# Out:
# S    270
# C    102
# Q     46
# Name: Embarked, dtype: int64

# %%
gender = pd.get_dummies(df['Sex'],drop_first = True)

# %%
gender.head()
# Out:
#    male
# 0     1
# 1     0
# 2     1
# 3     1
# 4     0

# %%
  df.drop(["Name"],axis=1)
  df.head(20)
# Out:
#     PassengerId  Pclass  ... Cabin Embarked
# 0           892       3  ...   NaN        Q
# 1           893       3  ...   NaN        S
# 2           894       2  ...   NaN        Q
# 3           895       3  ...   NaN        S
# 4           896       3  ...   NaN        S
# 5           897       3  ...   NaN        S
# 6           898       3  ...   NaN        Q
# 7           899       2  ...   NaN        S
# 8           900       3  ...   NaN        C
# 9           901       3  ...   NaN        S
# 10          902       3  ...   NaN        S
# 11          903       1  ...   NaN        S
# 12          904       1  ...   B45        S
# 13          905       2  ...   NaN        S
# 14          906       1  ...   E31        S
# 15          907       2  ...   NaN        C
# 16          908       2  ...   NaN        Q
# 17          909       3  ...   NaN        C
# 18          910       3  ...   NaN        S
# 19          911       3  ...   NaN        C
#
# [20 rows x 11 columns]

# %%
df.drop(["PassengerId"],axis=1)
df.head(15)
# Out:
#     PassengerId  Pclass  ... Cabin Embarked
# 0           892       3  ...   NaN        Q
# 1           893       3  ...   NaN        S
# 2           894       2  ...   NaN        Q
# 3           895       3  ...   NaN        S
# 4           896       3  ...   NaN        S
# 5           897       3  ...   NaN        S
# 6           898       3  ...   NaN        Q
# 7           899       2  ...   NaN        S
# 8           900       3  ...   NaN        C
# 9           901       3  ...   NaN        S
# 10          902       3  ...   NaN        S
# 11          903       1  ...   NaN        S
# 12          904       1  ...   B45        S
# 13          905       2  ...   NaN        S
# 14          906       1  ...   E31        S
#
# [15 rows x 11 columns]

# %%
df.drop(["Name"],axis=1)
df.head()
# Out:
#    PassengerId  Pclass  ... Cabin Embarked
# 0          892       3  ...   NaN        Q
# 1          893       3  ...   NaN        S
# 2          894       2  ...   NaN        Q
# 3          895       3  ...   NaN        S
# 4          896       3  ...   NaN        S
#
# [5 rows x 11 columns]

# %%
df1=df
df1.head()
# Out:
#    PassengerId  Pclass  ... Cabin Embarked
# 0          892       3  ...   NaN        Q
# 1          893       3  ...   NaN        S
# 2          894       2  ...   NaN        Q
# 3          895       3  ...   NaN        S
# 4          896       3  ...   NaN        S
#
# [5 rows x 11 columns]

# %%
Pcl=pd.get_dummies(df["Pclass"],drop_first=True)
Pcl.head()
# Out:
#    2  3
# 0  0  1
# 1  0  1
# 2  1  0
# 3  0  1
# 4  0  1

# %%
Em=pd.get_dummies(df["Embarked"],drop_first=True)
Em.head()
# Out:
#    Q  S
# 0  1  0
# 1  0  1
# 2  1  0
# 3  0  1
# 4  0  1

# %%
df.drop(["Embarked"],axis=1)
df.head(15)
# Out:
#     PassengerId  Pclass  ... Cabin Embarked
# 0           892       3  ...   NaN        Q
# 1           893       3  ...   NaN        S
# 2           894       2  ...   NaN        Q
# 3           895       3  ...   NaN        S
# 4           896       3  ...   NaN        S
# 5           897       3  ...   NaN        S
# 6           898       3  ...   NaN        Q
# 7           899       2  ...   NaN        S
# 8           900       3  ...   NaN        C
# 9           901       3  ...   NaN        S
# 10          902       3  ...   NaN        S
# 11          903       1  ...   NaN        S
# 12          904       1  ...   B45        S
# 13          905       2  ...   NaN        S
# 14          906       1  ...   E31        S
#
# [15 rows x 11 columns]

# %%
df.drop(["Name"],axis=1)
df.head(15)
# Out:
#     PassengerId  Pclass  ... Cabin Embarked
# 0           892       3  ...   NaN        Q
# 1           893       3  ...   NaN        S
# 2           894       2  ...   NaN        Q
# 3           895       3  ...   NaN        S
# 4           896       3  ...   NaN        S
# 5           897       3  ...   NaN        S
# 6           898       3  ...   NaN        Q
# 7           899       2  ...   NaN        S
# 8           900       3  ...   NaN        C
# 9           901       3  ...   NaN        S
# 10          902       3  ...   NaN        S
# 11          903       1  ...   NaN        S
# 12          904       1  ...   B45        S
# 13          905       2  ...   NaN        S
# 14          906       1  ...   E31        S
#
# [15 rows x 11 columns]

# %%
df=pd.concat([df,gender,Pcl,Em],axis=1)
df.head(15)
# Out:
#     PassengerId  Pclass  ...  Q  S
# 0           892       3  ...  1  0
# 1           893       3  ...  0  1
# 2           894       2  ...  1  0
# 3           895       3  ...  0  1
# 4           896       3  ...  0  1
# 5           897       3  ...  0  1
# 6           898       3  ...  1  0
# 7           899       2  ...  0  1
# 8           900       3  ...  0  0
# 9           901       3  ...  0  1
# 10          902       3  ...  0  1
# 11          903       1  ...  0  1
# 12          904       1  ...  0  1
# 13          905       2  ...  0  1
# 14          906       1  ...  0  1
#
# [15 rows x 16 columns]

# %%
df=df.drop(["PassengerId","Name","Sex","Ticket","Cabin","Pclass","Embarked"],axis=1)
df.head(15)
# Out:
#      Age  SibSp  Parch     Fare  male  2  3  Q  S
# 0   34.5      0      0   7.8292     1  0  1  1  0
# 1   47.0      1      0   7.0000     0  0  1  0  1
# 2   62.0      0      0   9.6875     1  1  0  1  0
# 3   27.0      0      0   8.6625     1  0  1  0  1
# 4   22.0      1      1  12.2875     0  0  1  0  1
# 5   14.0      0      0   9.2250     1  0  1  0  1
# 6   30.0      0      0   7.6292     0  0  1  1  0
# 7   26.0      1      1  29.0000     1  1  0  0  1
# 8   18.0      0      0   7.2292     0  0  1  0  0
# 9   21.0      2      0  24.1500     1  0  1  0  1
# 10   NaN      0      0   7.8958     1  0  1  0  1
# 11  46.0      0      0  26.0000     1  0  0  0  1
# 12  23.0      1      0  82.2667     0  0  0  0  1
# 13  63.0      1      0  26.0000     1  1  0  0  1
# 14  47.0      1      0  61.1750     0  0  0  0  1

# %%
df=pd.concat([df,df2],axis=1)
df.head(15)
# Out:
#      Age  SibSp  Parch     Fare  male  2  3  Q  S  PassengerId  Survived
# 0   34.5      0      0   7.8292     1  0  1  1  0          892         0
# 1   47.0      1      0   7.0000     0  0  1  0  1          893         1
# 2   62.0      0      0   9.6875     1  1  0  1  0          894         0
# 3   27.0      0      0   8.6625     1  0  1  0  1          895         0
# 4   22.0      1      1  12.2875     0  0  1  0  1          896         1
# 5   14.0      0      0   9.2250     1  0  1  0  1          897         0
# 6   30.0      0      0   7.6292     0  0  1  1  0          898         1
# 7   26.0      1      1  29.0000     1  1  0  0  1          899         0
# 8   18.0      0      0   7.2292     0  0  1  0  0          900         1
# 9   21.0      2      0  24.1500     1  0  1  0  1          901         0
# 10   NaN      0      0   7.8958     1  0  1  0  1          902         0
# 11  46.0      0      0  26.0000     1  0  0  0  1          903         0
# ...

# %%
df=df.drop(["PassengerId"],axis=1)
df.head(15)
# Out:
#      Age  SibSp  Parch     Fare  male  2  3  Q  S  Survived
# 0   34.5      0      0   7.8292     1  0  1  1  0         0
# 1   47.0      1      0   7.0000     0  0  1  0  1         1
# 2   62.0      0      0   9.6875     1  1  0  1  0         0
# 3   27.0      0      0   8.6625     1  0  1  0  1         0
# 4   22.0      1      1  12.2875     0  0  1  0  1         1
# 5   14.0      0      0   9.2250     1  0  1  0  1         0
# 6   30.0      0      0   7.6292     0  0  1  1  0         1
# 7   26.0      1      1  29.0000     1  1  0  0  1         0
# 8   18.0      0      0   7.2292     0  0  1  0  0         1
# 9   21.0      2      0  24.1500     1  0  1  0  1         0
# 10   NaN      0      0   7.8958     1  0  1  0  1         0
# 11  46.0      0      0  26.0000     1  0  0  0  1         0
# 12  23.0      1      0  82.2667     0  0  0  0  1         1
# 13  63.0      1      0  26.0000     1  1  0  0  1         0
# 14  47.0      1      0  61.1750     0  0  0  0  1         1

# %%
df.isnull().sum()
# Out:
# Age         86
# SibSp        0
# Parch        0
# Fare         1
# male         0
# 2            0
# 3            0
# Q            0
# S            0
# Survived     0
# dtype: int64

# %%
y=df["Survived"]
X=df.drop("Survived",axis=1)

# %%
df.head()
# Out:
#     Age  SibSp  Parch     Fare  male  2  3  Q  S  Survived
# 0  34.5      0      0   7.8292     1  0  1  1  0         0
# 1  47.0      1      0   7.0000     0  0  1  0  1         1
# 2  62.0      0      0   9.6875     1  1  0  1  0         0
# 3  27.0      0      0   8.6625     1  0  1  0  1         0
# 4  22.0      1      1  12.2875     0  0  1  0  1         1

# %%
df.head(50)
# Out:
#      Age  SibSp  Parch      Fare  male  2  3  Q  S  Survived
# 0   34.5      0      0    7.8292     1  0  1  1  0         0
# 1   47.0      1      0    7.0000     0  0  1  0  1         1
# 2   62.0      0      0    9.6875     1  1  0  1  0         0
# 3   27.0      0      0    8.6625     1  0  1  0  1         0
# 4   22.0      1      1   12.2875     0  0  1  0  1         1
# 5   14.0      0      0    9.2250     1  0  1  0  1         0
# 6   30.0      0      0    7.6292     0  0  1  1  0         1
# 7   26.0      1      1   29.0000     1  1  0  0  1         0
# 8   18.0      0      0    7.2292     0  0  1  0  0         1
# 9   21.0      2      0   24.1500     1  0  1  0  1         0
# 10   NaN      0      0    7.8958     1  0  1  0  1         0
# 11  46.0      0      0   26.0000     1  0  0  0  1         0
# 12  23.0      1      0   82.2667     0  0  0  0  1         1
# 13  63.0      1      0   26.0000     1  1  0  0  1         0
# ...

# %%
df.isnull().sum()
# Out:
# Age         86
# SibSp        0
# Parch        0
# Fare         1
# male         0
# 2            0
# 3            0
# Q            0
# S            0
# Survived     0
# dtype: int64

# %%
df=df.drop(["Age"],axis=1)
df.head(200)
# Out:
#      SibSp  Parch      Fare  male  2  3  Q  S  Survived
# 0        0      0    7.8292     1  0  1  1  0         0
# 1        1      0    7.0000     0  0  1  0  1         1
# 2        0      0    9.6875     1  1  0  1  0         0
# 3        0      0    8.6625     1  0  1  0  1         0
# 4        1      1   12.2875     0  0  1  0  1         1
# 5        0      0    9.2250     1  0  1  0  1         0
# 6        0      0    7.6292     0  0  1  1  0         1
# 7        1      1   29.0000     1  1  0  0  1         0
# 8        0      0    7.2292     0  0  1  0  0         1
# 9        2      0   24.1500     1  0  1  0  1         0
# 10       0      0    7.8958     1  0  1  0  1         0
# 11       0      0   26.0000     1  0  0  0  1         0
# 12       1      0   82.2667     0  0  0  0  1         1
# 13       1      0   26.0000     1  1  0  0  1         0
# 14       1      0   61.1750     0  0  0  0  1         1
# 15       1      0   27.7208     0  1  0  0  0         1
# ...

# %%
df.head(200)
# Out:
#      SibSp  Parch      Fare  male  2  3  Q  S  Survived
# 0        0      0    7.8292     1  0  1  1  0         0
# 1        1      0    7.0000     0  0  1  0  1         1
# 2        0      0    9.6875     1  1  0  1  0         0
# 3        0      0    8.6625     1  0  1  0  1         0
# 4        1      1   12.2875     0  0  1  0  1         1
# 5        0      0    9.2250     1  0  1  0  1         0
# 6        0      0    7.6292     0  0  1  1  0         1
# 7        1      1   29.0000     1  1  0  0  1         0
# 8        0      0    7.2292     0  0  1  0  0         1
# 9        2      0   24.1500     1  0  1  0  1         0
# 10       0      0    7.8958     1  0  1  0  1         0
# 11       0      0   26.0000     1  0  0  0  1         0
# 12       1      0   82.2667     0  0  0  0  1         1
# 13       1      0   26.0000     1  1  0  0  1         0
# 14       1      0   61.1750     0  0  0  0  1         1
# 15       1      0   27.7208     0  1  0  0  0         1
# ...

# %%
df = df.dropna(how='any',axis=0)

# %%
df.isnull().sum()
# Out:
# SibSp       0
# Parch       0
# Fare        0
# male        0
# 2           0
# 3           0
# Q           0
# S           0
# Survived    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_test,X_train,y_test,y_train=train_test_split(X,y,test_size=0.40,random_state=1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel=LogisticRegression()

# %%
logmodel.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-652-0b508b2e1562> in <module>()
# ----> 1 logmodel.fit(X_train,y_train)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py in fit(self, X, y, sample_weight)
#    1530
#    1531         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# -> 1532                          accept_large_sparse=solver != 'liblinear')
#    1533         check_classification_targets(y)
#    1534         self.classes_ = np.unique(y)
#
# ...

# %%
predictions=logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
classification_report(y_test,predictions)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,predictions)
